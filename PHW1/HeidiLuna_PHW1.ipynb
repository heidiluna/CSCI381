-- %% [markdown]
-- # PHW#1 : Single Table Queries

-- %% [markdown]
-- ## Chapter 2: Single-Table Queries Exercies

-- %% [markdown]
-- ## Exercise 1:
--
-- Return orders placed on June 2015
--
-- <u>Tables Involved:</u> TSQLV6 Database, Sales.Order Table
--
-- <u>Desired Output:</u>
--
-- ```
--
-- orderid     orderdate  custid      empid
-- ----------- ---------- ----------- -----------
-- 10555       2015-06-02 71          6
-- 10556       2015-06-03 73          2
-- 10557       2015-06-03 44          9
-- 10558       2015-06-04 4           1
-- 10559       2015-06-05 7           6
-- 10560       2015-06-06 25          8
-- 10561       2015-06-06 24          2
-- 10562       2015-06-09 66          1
-- 10563       2015-06-10 67          2
-- 10564       2015-06-10 65          4
-- ...
--
-- (30 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT OrderID, OrderDate, CustID, EmpID
FROM Sales.Orders
WHERE OrderDate >= '2015-06-01'
  AND OrderDate < '2015-07-01';

-- Northwinds2022TSQLV7: 
USE Northwinds2022TSQLV7;
SELECT OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
WHERE OrderDate >= '2015-06-01'
  AND OrderDate < '2015-07-01';
-- Out:
-- (30 rows affected)
-- (30 rows affected)
-- Total execution time: 00:00:00.028
-- ...

-- %% [markdown]
-- ## Exercise 2:
--
-- Return orders placed on the last day of the month
--
-- <u>Tables Involved:</u> Sales.Order Table
--
-- <u>Desired Output:</u>
-- ```
-- orderid     orderdate  custid      empid
-- ----------- ---------- ----------- -----------
-- 10269       2014-07-31 89          5
-- 10317       2014-09-30 48          6
-- 10343       2014-10-31 44          4
-- 10399       2014-12-31 83          8
-- 10432       2015-01-31 75          3
-- 10460       2015-02-28 24          8
-- 10461       2015-02-28 46          1
-- 10490       2015-03-31 35          7
-- 10491       2015-03-31 28          8
-- 10522       2015-04-30 44          4
-- ...
--
-- (26 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT OrderID, OrderDate, CustID, EmpID
FROM Sales.Orders
WHERE OrderDate = DATEADD(DAY, -1, DATEADD(MONTH, DATEDIFF(MONTH, 0, OrderDate) + 1, 0));

-- Northwinds2022TSQLV7: 
USE Northwinds2022TSQLV7;
SELECT OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
WHERE OrderDate = DATEADD(DAY, -1, DATEADD(MONTH, DATEDIFF(MONTH, 0, OrderDate) + 1, 0));
-- Out:
-- (26 rows affected)
-- (26 rows affected)
-- Total execution time: 00:00:00.048
-- ...

-- %% [markdown]
-- ## Exercise 3:
--
-- Return employees with last name containing the letter 'e' twice or more
--
-- <u>Tables Involved:</u> HR.Employees Table
--
-- <u>Desired Output:</u>
-- ```
-- empid       firstname  lastname
-- ----------- ---------- --------------------
-- 4           Yael       Peled
-- 5           Sven       Mortensen
--
-- (2 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT empid, firstname, lastname
FROM HR.Employees
WHERE lastname LIKE '%e%e%';

-- Northwinds2022TSQLV7:
USE Northwinds2022TSQLV7;
SELECT EmployeeId, EmployeeFirstName, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName LIKE '%e%e%';
-- Out:
-- (2 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.055
-- <table><tr><th>empid</th><th>firstname</th><th>lastname</th></tr><tr><td>4</td><td>Yael</td><td>Peled</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>EmployeeFirstName</th><th>EmployeeLastName</th></tr><tr><td>4</td><td>Yael</td><td>Peled</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td></tr></table>

-- %% [markdown]
-- ## Exercise 4:
--
-- Return orders with total value(qty*unitprice) greater than 10000 sorted by total value
--
-- <u>Tables Involved:</u> Sales.OrderDetails Table
--
-- <u>Desired Output:</u>
-- ```
-- orderid     totalvalue
-- ----------- ---------------------
-- 10865       17250.00
-- 11030       16321.90
-- 10981       15810.00
-- 10372       12281.20
-- 10424       11493.20
-- 10817       11490.70
-- 10889       11380.00
-- 10417       11283.20
-- 10897       10835.24
-- 10353       10741.60
-- 10515       10588.50
-- 10479       10495.60
-- 10540       10191.70
-- 10691       10164.80
--
-- (14 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT orderid, SUM(qty*unitprice) AS totalvalue
FROM Sales.OrderDetails
GROUP BY orderid
HAVING SUM(qty*unitprice) > 10000
ORDER BY totalvalue DESC; 

-- Northwinds2022TSQLV7:
USE Northwinds2022TSQLV7;
SELECT OrderId, SUM(Quantity*UnitPrice) AS totalvalue
FROM Sales.OrderDetail
GROUP BY OrderId
HAVING SUM(Quantity*UnitPrice) > 10000
ORDER BY totalvalue DESC;
-- Out:
-- (14 rows affected)
-- (14 rows affected)
-- Total execution time: 00:00:00.054
-- <table><tr><th>orderid</th><th>totalvalue</th></tr><tr><td>10865</td><td>17250.00</td></tr><tr><td>11030</td><td>16321.90</td></tr><tr><td>10981</td><td>15810.00</td></tr><tr><td>10372</td><td>12281.20</td></tr><tr><td>10424</td><td>11493.20</td></tr><tr><td>10817</td><td>11490.70</td></tr><tr><td>10889</td><td>11380.00</td></tr><tr><td>10417</td><td>11283.20</td></tr><tr><td>10897</td><td>10835.24</td></tr><tr><td>10353</td><td>10741.60</td></tr><tr><td>10515</td><td>10588.50</td></tr><tr><td>10479</td><td>10495.60</td></tr><tr><td>10540</td><td>10191.70</td></tr><tr><td>10691</td><td>10164.80</td></tr></table>
-- ...

-- %% [markdown]
-- ## Exercise 5:
--
-- Write a query against the HR.Employees table that returns employees with a last name that starts with a lower case letter. Remember that the collation of the sample database is case insensitive (Latin1_General_CI_AS). For simplicity, you can assume that only English letters are used in the employee last names.
--
-- <u>Tables Involved:</u> TSQLV4 Database, Sales.Order Table
--
-- <u>Desired Output:</u> Sales.OrderDetails table
-- ```
-- empid       lastname
-- ----------- --------------------
--
-- (0 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT empid, lastname
FROM HR.Employees
WHERE lastname COLLATE Latin1_General_CS_As LIKE N'[abcdefghijklmnopqrstuvwxyz]%'

-- Northwinds2022TSQLV7: 
USE Northwinds2022TSQLV7;
SELECT EmployeeId, EmployeeLastName
FROM HumanResources.Employee
WHERE EmployeeLastName COLLATE Latin1_General_CS_As LIKE N'[abcdefghijklmnopqrstuvwxyz]%'
-- Out:
-- (0 rows affected)
-- (0 rows affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>empid</th><th>lastname</th></tr></table>
-- <table><tr><th>EmployeeId</th><th>EmployeeLastName</th></tr></table>

-- %% [markdown]
-- ## Exercise 6:
--
-- Explain the difference between the following two queries
--
-- **<u>Answer:</u>**  The key difference between both queries is that the _WHERE_ clause is row filter in query 1, whereas the _HAVING_ clause is a group filter in query 2.
--
-- In query 1 we see that orders placed before May 2022 are the only ones filtered. Orders placed before May 2022 are grouped by employee ID and query 1 returns the number of orders each employee handled before May 2022, not including orders placed on May 2022 and further.
--
-- On the otherhand, Query 2 groups all orders by employee ID and only filters groups having a maximum order date activity prior to May 2022. Therefore, Query 2 returns the total number of orders handled by an employee who hasnt handled any orders since May 2022.
--
-- ```
-- -- Query 1
-- SELECT empid, COUNT(*) AS numorders
-- FROM Sales.Orders
-- WHERE orderdate < '20160501'
-- GROUP BY empid;
--
-- -- Query 2
-- SELECT empid, COUNT(*) AS numorders
-- FROM Sales.Orders
-- GROUP BY empid
-- HAVING MAX(orderdate) < '20160501';
--
-- ```
--
-- ### Results of both queries:

-- %%
-- Query 1
USE TSQLV4;
SELECT empid, COUNT(*) AS numorders
FROM Sales.Orders
WHERE orderdate < '20160501'
GROUP BY empid;

-- Query 2
USE TSQLV4;
SELECT empid, COUNT(*) AS numorders
FROM Sales.Orders
GROUP BY empid
HAVING MAX(orderdate) < '20160501';
-- Out:
-- (9 rows affected)
-- (4 rows affected)
-- Total execution time: 00:00:00.046
-- <table><tr><th>empid</th><th>numorders</th></tr><tr><td>1</td><td>118</td></tr><tr><td>2</td><td>94</td></tr><tr><td>3</td><td>127</td></tr><tr><td>4</td><td>154</td></tr><tr><td>5</td><td>42</td></tr><tr><td>6</td><td>67</td></tr><tr><td>7</td><td>70</td></tr><tr><td>8</td><td>101</td></tr><tr><td>9</td><td>43</td></tr></table>
-- <table><tr><th>empid</th><th>numorders</th></tr><tr><td>9</td><td>43</td></tr><tr><td>3</td><td>127</td></tr><tr><td>6</td><td>67</td></tr><tr><td>5</td><td>42</td></tr></table>

-- %% [markdown]
-- ## Exercise 7:
--
-- Return the three ship countries with the highest average freight for orders placed in 2015
--
-- <u>Tables Involved:</u> Sales.Order Table
--
-- <u>Desired Output:</u>
-- ```
-- shipcountry     avgfreight
-- --------------- ---------------------
-- Austria         178.3642
-- Switzerland     117.1775
-- Sweden          105.16
--
-- (3 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT TOP 3
       ShipCountry,
       AVG(Freight) AS AvgFreight
FROM Sales.Orders
WHERE YEAR(OrderDate) = 2015
GROUP BY ShipCountry
ORDER BY AvgFreight DESC;

 -- Northwinds2022TSQLV7: 
 USE Northwinds2022TSQLV7;
SELECT TOP 3
       ShipToCountry,
       AVG(Freight) AS AvgFreight
FROM Sales.[Order]
WHERE YEAR(OrderDate) = 2015
GROUP BY ShipToCountry
ORDER BY AvgFreight DESC;
-- Out:
-- (3 rows affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.070
-- <table><tr><th>ShipCountry</th><th>AvgFreight</th></tr><tr><td>Austria</td><td>178.3642</td></tr><tr><td>Switzerland</td><td>117.1775</td></tr><tr><td>Sweden</td><td>105.16</td></tr></table>
-- <table><tr><th>ShipToCountry</th><th>AvgFreight</th></tr><tr><td>Austria</td><td>178.3642</td></tr><tr><td>Switzerland</td><td>117.1775</td></tr><tr><td>Sweden</td><td>105.16</td></tr></table>

-- %% [markdown]
-- ## Exercise 8:
--
-- Calculate row mubers for orders based on the order date ordering (using order is as tiebreaker) for each customer seprately
--
-- <u>Tables Involved:</u> TSQLV4 Database, Sales.Order Table
--
-- <u>Desired Output:</u>
--
-- ```
-- custid      orderdate  orderid     rownum
-- ----------- ---------- ----------- --------------------
-- 1           2015-08-25 10643       1
-- 1           2015-10-03 10692       2
-- 1           2015-10-13 10702       3
-- 1           2016-01-15 10835       4
-- 1           2016-03-16 10952       5
-- 1           2016-04-09 11011       6
-- 2           2014-09-18 10308       1
-- 2           2015-08-08 10625       2
-- 2           2015-11-28 10759       3
-- 2           2016-03-04 10926       4
-- ...
--
-- (830 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT custid, orderdate, orderid,
  ROW_NUMBER() OVER(PARTITION BY custid ORDER BY orderdate, orderid) AS rownum
FROM Sales.Orders
ORDER BY custid, rownum;

-- Northwinds2022TSQLV7:
USE Northwinds2022TSQLV7;
SELECT CustomerId, OrderDate, OrderId,
  ROW_NUMBER() OVER(PARTITION BY CustomerId ORDER BY OrderDate, OrderId) AS rownum
FROM Sales.[Order]
ORDER BY CustomerId, rownum;
-- Out:
-- (830 rows affected)
-- (830 rows affected)
-- Total execution time: 00:00:00.044
-- ...

-- %% [markdown]
-- ## Exercise 9:
--
-- Figure out and return for each employee the gender based on the title of courtesy
--
-- Ms., Mrs. -Female, Mr. -Male, Dr. -Unknown
--
-- <u>Tables Involved:</u> HR.Employees Table
--
-- <u>Desired Output:</u>
--
-- ```
-- empid       firstname  lastname             titleofcourtesy           gender
-- ----------- ---------- -------------------- ------------------------- -------
-- 1           Sara       Davis                Ms.                       Female
-- 2           Don        Funk                 Dr.                       Unknown
-- 3           Judy       Lew                  Ms.                       Female
-- 4           Yael       Peled                Mrs.                      Female
-- 5           Sven       Mortensen            Mr.                       Male
-- 6           Paul       Suurs                Mr.                       Male
-- 7           Russell    King                 Mr.                       Male
-- 8           Maria      Cameron              Ms.                       Female
-- 9           Patricia   Doyle                Ms.                       Female
--
-- (9 row(s) affected)
--
-- ```

-- %%
-- TSQLV4 Database: 
USE TSQLV4;
SELECT empid, firstname, lastname, titleofcourtesy,
  CASE titleofcourtesy
    WHEN 'Ms.'  THEN 'Female'
    WHEN 'Mrs.' THEN 'Female'
    WHEN 'Mr.'  THEN 'Male'
    ELSE             'Unknown'
  END AS gender
FROM HR.Employees;

-- Northwinds2022TSQLV7:
USE Northwinds2022TSQLV7;
SELECT EmployeeId, EmployeeFirstName, EmployeeLastName, EmployeeTitleOfCourtesy,
  CASE EmployeeTitleOfCourtesy
    WHEN 'Ms.'  THEN 'Female'
    WHEN 'Mrs.' THEN 'Female'
    WHEN 'Mr.'  THEN 'Male'
    ELSE             'Unknown'
  END AS gender
FROM HumanResources.Employee;
-- Out:
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>empid</th><th>firstname</th><th>lastname</th><th>titleofcourtesy</th><th>gender</th></tr><tr><td>1</td><td>Sara</td><td>Davis</td><td>Ms.</td><td>Female</td></tr><tr><td>2</td><td>Don</td><td>Funk</td><td>Dr.</td><td>Unknown</td></tr><tr><td>3</td><td>Judy</td><td>Lew</td><td>Ms.</td><td>Female</td></tr><tr><td>4</td><td>Yael</td><td>Peled</td><td>Mrs.</td><td>Female</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td><td>Mr.</td><td>Male</td></tr><tr><td>6</td><td>Paul</td><td>Suurs</td><td>Mr.</td><td>Male</td></tr><tr><td>7</td><td>Russell</td><td>King</td><td>Mr.</td><td>Male</td></tr><tr><td>8</td><td>Maria</td><td>Cameron</td><td>Ms.</td><td>Female</td></tr><tr><td>9</td><td>Patricia</td><td>Doyle</td><td>Ms.</td><td>Female</td></tr></table>
-- ...

-- %% [markdown]
-- ## Exercise 10:
--
-- Return for each customer the customer ID and region
-- sort the rows in the output by region
-- having NULLs sort last (after non-NULL values)
--  Note that the default in T-SQL is that NULLs sort first
--
-- <u>Tables Involved:</u> <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">Sales.Customers table</span>
--
-- <u>Desired Output:</u>
-- ```
-- custid      region
-- ----------- ---------------
-- 55          AK
-- 10          BC
-- 42          BC
-- 45          CA
-- 37          Co. Cork
-- 33          DF
-- 71          ID
-- 38          Isle of Wight
-- 46          Lara
-- 78          MT
-- ...
-- 1           NULL
-- 2           NULL
-- 3           NULL
-- 4           NULL
-- 5           NULL
-- 6           NULL
-- 7           NULL
-- 8           NULL
-- 9           NULL
-- 11          NULL
-- ...
--
-- (91 row(s) affected)
--
-- ```

-- %%
-- TSQLV6 Database: 
USE TSQLV4;
SELECT custid, region
FROM Sales.Customers
ORDER BY
  CASE WHEN region IS NULL THEN 1 ELSE 0 END, region; 

-- Northwinds2022TSQLV7: 
USE Northwinds2022TSQLV7;
SELECT CustomerId, CustomerRegion
FROM Sales.Customer
ORDER BY
  CASE WHEN CustomerRegion IS NULL THEN 1 ELSE 0 END, CustomerRegion;
-- Out:
-- (91 rows affected)
-- (91 rows affected)
-- Total execution time: 00:00:00.033
-- ...

-- %% [markdown]
-- # Propositions:
--
-- ## **Goal:** Build propostions based on the given queries
--
-- ## Proposition 1:
--
-- After running the following query given, I saw that this query will return a list of employees who have processed <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">more than one order for the customer with custid&nbsp;</span>    <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">&nbsp;71, grouped by the year the orders were placed, and will sort the results by employee ID and year.</span>

-- %%
SELECT empid, YEAR(orderdate) AS orderyear, COUNT(*) AS numorders
FROM Sales.Orders
WHERE custid = 71
GROUP BY empid, YEAR(orderdate)
HAVING COUNT(*) > 1
ORDER BY empid, orderyear;
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:00.024
-- <table><tr><th>empid</th><th>orderyear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr></table>

-- %% [markdown]
-- ## Proposition 2:
--
-- <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">After running the following query given, th</span>is query will return the 5 most recent orders from the Sales.Orders table. <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">It selects the orderid</span><span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">, orderdate, custid, and empid&nbsp;</span>   <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">columns from the Sales.Orders&nbsp;</span>   <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">table and orders the results in descending order of&nbsp;</span>   orderdate<span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">. The top (5)&nbsp;</span>   <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">clause limits the result set to only the top 5 rows.</span>

-- %%
SELECT TOP (5) orderid, orderdate, custid, empid
FROM Sales.Orders
ORDER BY orderdate DESC;
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.032
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11073</td><td>2016-05-05</td><td>58</td><td>2</td></tr></table>

-- %% [markdown]
-- ## Proposition 3:
--
-- <span style="color: var(--vscode-foreground); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">After running the following query given, th</span>is query will select <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">employee IDs (empid</span><span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">) and last names&nbsp;</span>  <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">from the HR.Employees&nbsp;</span>  <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">table where the last name starts with a letter between A and E.</span>

-- %%
SELECT empid, lastname
FROM HR.Employees
WHERE lastname LIKE N'[A-E]%';
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>empid</th><th>lastname</th></tr><tr><td>8</td><td>Cameron</td></tr><tr><td>1</td><td>Davis</td></tr><tr><td>9</td><td>Doyle</td></tr></table>

-- %% [markdown]
-- ## Proposition 4:
--
-- <span style="color: var(--vscode-foreground); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">After running the following query given, th</span>is query <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">provide a result set with each order detail along with its computed value after applying any discount.</span>

-- %%
SELECT orderid, productid, qty, unitprice, discount,
  qty * unitprice * (1 - discount) AS val
FROM Sales.OrderDetails;
-- Out:
-- (2155 rows affected)
-- Total execution time: 00:00:00.019
-- ...

-- %% [markdown]
-- ## Proposition 5:
--
-- <span style="color: var(--vscode-foreground); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">After running the following query given, th</span>is query <span style="font-family: -apple-system, BlinkMacSystemFont, sans-serif; color: var(--vscode-foreground);">will return all orders from January 1, 2016, onwards that were processed by employees with IDs 1, 3, or 5.</span>

-- %%
SELECT orderid, empid, orderdate
FROM Sales.Orders
WHERE orderdate >= '20160101'
  AND empid IN(1, 3, 5);
-- Out:
-- (93 rows affected)
-- Total execution time: 00:00:00.012
-- ...
